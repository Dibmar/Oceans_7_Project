# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style('darkgrid')

# %%
import EDA
EDA
# Out:
# EDA lib ready
# <module 'EDA' from 'f:\\Programacion\\1.BOOTCAMP\\Proyectos\\Oceans_7_Project\\EDA.py'>

# %%
kali = pd.read_csv(r'F:\Programacion\1.BOOTCAMP\data\trabajo_interdisciplinar\TráficoNormal_kali_Clara_8jul2020.csv')
kali.head(1)
# Out:
#    No.                          Arrival Time  Time  \
# 0    1  Jul  8, 2020 17:45:43.050968825 CEST   0.0
#
#    Time delta from previous captured frame    Source  Source Port  \
# 0                                      0.0  10.0.2.9          NaN
#
#   Source GeoIP Destination  Destination Port Destination GeoIP Protocol  \
# 0          NaN  10.0.2.255               NaN               NaN     NBNS
#
#    Length Request Method                        Arrival Time.1  \
# 0      92            NaN  Jul  8, 2020 17:45:43.050968825 CEST
#
#                          Arrival Time.2                       Info
# 0  Jul  8, 2020 17:45:43.050968825 CEST  Name query NB EMPRESA<1c>

# %%
EDA.general_info(kali)
# Out:
# -dtype, length and name of columns-
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17007 entries, 0 to 17006
# Data columns (total 16 columns):
# No.                                        17007 non-null int64
# Arrival Time                               17007 non-null object
# Time                                       17007 non-null float64
# Time delta from previous captured frame    17007 non-null float64
# Source                                     17007 non-null object
# Source Port                                16728 non-null float64
# Source GeoIP                               9462 non-null object
# Destination                                17007 non-null object
# Destination Port                           16728 non-null float64
# Destination GeoIP                          7418 non-null object
# Protocol                                   17007 non-null object
# Length                                     17007 non-null int64
# Request Method                             101 non-null object
# Arrival Time.1                             17007 non-null object
# Arrival Time.2                             17007 non-null object
# Info                                       17007 non-null object
# dtypes: float64(4), int64(2), object(10)
# memory usage: 2.1+ MB
# None
#
# Index(['No.', 'Arrival Time', 'Time',
#        'Time delta from previous captured frame', 'Source', 'Source Port',
#        'Source GeoIP', 'Destination', 'Destination Port', 'Destination GeoIP',
#        'Protocol', 'Length', 'Request Method', 'Arrival Time.1',
#        'Arrival Time.2', 'Info'],
#       dtype='object')
#
# (17007, 16)
#
# -Presence of NaNs in df-
# No.                                        False
# Arrival Time                               False
# Time                                       False
# Time delta from previous captured frame    False
# Source                                     False
# Source Port                                 True
# Source GeoIP                                True
# Destination                                False
# Destination Port                            True
# Destination GeoIP                           True
# Protocol                                   False
# Length                                     False
# Request Method                              True
# Arrival Time.1                             False
# Arrival Time.2                             False
# Info                                       False
# dtype: bool
#
# -Number of NaNs in df-
# No.                                            0
# Arrival Time                                   0
# Time                                           0
# Time delta from previous captured frame        0
# Source                                         0
# Source Port                                  279
# Source GeoIP                                7545
# Destination                                    0
# Destination Port                             279
# Destination GeoIP                           9589
# Protocol                                       0
# Length                                         0
# Request Method                             16906
# Arrival Time.1                                 0
# Arrival Time.2                                 0
# Info                                           0
# dtype: int64

# %%
col_names = ['index', 'date', 'time', 'duration', 'source',
       'src_port', 'src_geo', 'destination', 'dest_port',
       'dest_geo', 'protocol', 'length', 'request_method','arrival_time_1', 'arrival_time_2', 'info']

if len(kali.columns) == len (col_names):
       kali.columns = col_names
else:
       print(f'Longitud erronea: {len(kali.columns)} del df contra {len (col_names)} de la lista')
       pass

# %% [markdown]
# # kali_frame

# %%
kali_time = kali[['index','date', 'time', 'duration']]
kali_time
# Out:
#        index                                  date        time      duration
# 0          1  Jul  8, 2020 17:45:43.050968825 CEST    0.000000  0.000000e+00
# 1          2  Jul  8, 2020 17:45:43.728318228 CEST    0.677349  6.773494e-01
# 2          3  Jul  8, 2020 17:45:44.413510872 CEST    1.362542  6.851926e-01
# 3          4  Jul  8, 2020 17:46:03.848724881 CEST   20.797756  1.943521e+01
# 4          5  Jul  8, 2020 17:46:03.848765610 CEST   20.797797  4.072900e-05
# ...      ...                                   ...         ...           ...
# 17002  17003  Jul  8, 2020 17:49:32.474043222 CEST  229.423074  7.073900e-05
# 17003  17004  Jul  8, 2020 17:49:32.475291497 CEST  229.424323  1.248275e-03
# 17004  17005  Jul  8, 2020 17:49:32.475291616 CEST  229.424323  1.190000e-07
# 17005  17006  Jul  8, 2020 17:49:32.475327260 CEST  229.424358  3.564400e-05
# 17006  17007  Jul  8, 2020 17:49:32.475354390 CEST  229.424386  2.713000e-05
#
# [17007 rows x 4 columns]

# %%
(kali.arrival_time_1 == kali.arrival_time_2).any()
# Out:
# True

# %%
info_time = kali_time['time'].describe()
info_time
# Out:
# count    17007.000000
# mean       116.446142
# std         55.463130
# min          0.000000
# 25%         53.053953
# 50%        135.127543
# 75%        159.213869
# max        229.424386
# Name: time, dtype: float64

# %%
kali_time['duration'].plot(colors = 'darkred', alpha = 0.95)
plt.xlabel('Attack Id')
plt.ylabel('Duration of the attacks (s)')
# fig.savefig('test.jpg')
plt.show()

# %%
kali_time['date'].value_counts()
# Out:
# Jul  8, 2020 17:47:58.037945170 CEST    1
# Jul  8, 2020 17:48:26.465741789 CEST    1
# Jul  8, 2020 17:48:36.935996503 CEST    1
# Jul  8, 2020 17:46:30.848922971 CEST    1
# Jul  8, 2020 17:48:00.718241420 CEST    1
#                                        ..
# Jul  8, 2020 17:46:30.867563967 CEST    1
# Jul  8, 2020 17:48:26.397452781 CEST    1
# Jul  8, 2020 17:48:55.740755511 CEST    1
# Jul  8, 2020 17:47:02.171378284 CEST    1
# Jul  8, 2020 17:48:21.291955792 CEST    1
# Name: date, Length: 17007, dtype: int64

# %% [markdown]
# # kali_ip

# %%
kali.columns
# Out:
# Index(['index', 'date', 'time', 'duration', 'source', 'src_port', 'src_geo',
#        'destination', 'dest_port', 'dest_geo', 'protocol', 'length',
#        'request_method', 'arrival_time_1', 'arrival_time_2', 'info'],
#       dtype='object')

# %%
kali_local = kali[['index' , 'source', 'src_port', 'src_geo',
       'destination', 'dest_port', 'dest_geo']]
kali_local.head(2)
# Out:
#    index    source  src_port src_geo destination  dest_port dest_geo
# 0      1  10.0.2.9       NaN     NaN  10.0.2.255        NaN      NaN
# 1      2  10.0.2.9       NaN     NaN  10.0.2.255        NaN      NaN

# %%
EDA.null_count(kali_local)
# Out:
# Presence of null in clolumns:
# index          False
# source         False
# src_port        True
# src_geo         True
# destination    False
# dest_port       True
# dest_geo        True
# dtype: bool
#
# Number of null in columns:
# index             0
# source            0
# src_port        279
# src_geo        7545
# destination       0
# dest_port       279
# dest_geo       9589
# dtype: int64

# %%
EDA.value_counter(kali_local)
# Out:
# index:
# 2047     1
# 4711     1
# 2692     1
# 12931    1
# 14978    1
#         ..
# 5432     1
# 11567    1
# 9518     1
# 15661    1
# 2049     1
# Name: index, Length: 17007, dtype: int64
# ----------------
#
# source:
# 10.0.2.12                    7426
# 74.125.168.39                2815
# 31.13.83.4                   1548
# 216.58.201.174                953
# 172.217.17.4                  669
# 104.16.37.47                  632
# 172.217.168.163               425
# 216.58.201.173                355
# 185.70.41.130                 297
# 172.217.16.246                287
# 31.13.83.36                   257
# 216.58.211.238                250
# 216.58.209.78                 213
# 216.58.211.227                107
# 80.58.61.254                   82
# 172.217.17.3                   67
# 216.58.211.226                 61
# 216.58.209.67                  56
# 104.17.214.67                  56
# 10.0.2.9                       56
# fe80::2d94:75f1:ca9a:51b6      53
# 172.217.168.161                47
# 31.13.83.1                     42
# 104.18.27.18                   36
# 216.58.209.66                  25
# 93.184.220.29                  24
# 172.217.16.228                 20
# 172.217.17.14                  20
# 172.217.16.238                 18
# 172.217.168.174                16
# 172.217.168.170                15
# 31.13.83.8                     14
# 216.58.211.34                  12
# 104.26.12.69                   12
# 172.217.17.10                  11
# 172.217.17.6                   10
# 216.58.201.131                 10
# 216.58.211.35                   5
# PcsCompu_5f:32:94               2
# 10.0.2.3                        1
# PcsCompu_43:d9:56               1
# PcsCompu_7d:2b:f3               1
# Name: source, dtype: int64
# ----------------
#
# src_port:
# 443.0      9284
# 57140.0    1275
# 41354.0    1022
# 51934.0     811
# 56256.0     568
#            ...
# 36186.0       2
# 36196.0       2
# 36206.0       2
# 36184.0       2
# 36208.0       2
# Name: src_port, Length: 77, dtype: int64
# ----------------
#
# src_geo:
# US                   5156
# Mountain View, US    2042
# IE                   1861
# CH                    297
# Madrid, ES             82
# London, GB             24
# Name: src_geo, dtype: int64
# ----------------
#
# destination:
# 10.0.2.12            9468
# 31.13.83.4           1444
# 74.125.168.39        1320
# 216.58.201.174        811
# 172.217.17.4          590
# 172.217.168.163       408
# 185.70.41.130         340
# 31.13.83.36           336
# 216.58.201.173        290
# 104.16.37.47          270
# 216.58.211.238        254
# 172.217.16.246        204
# 216.58.209.78         158
# 216.58.211.227        115
# 216.58.211.226         87
# 104.17.214.67          82
# 80.58.61.254           82
# 31.13.83.1             80
# 172.217.17.3           76
# 104.18.27.18           67
# 172.217.168.161        59
# 216.58.209.67          50
# 239.255.255.250        42
# ff02::c                36
# 216.58.209.66          30
# 172.217.17.14          30
# 93.184.220.29          29
# 172.217.168.174        27
# 172.217.16.238         27
# 172.217.16.228         25
# 172.217.168.170        24
# 31.13.83.8             22
# 216.58.211.34          19
# 104.26.12.69           17
# 172.217.17.6           17
# 172.217.17.10          17
# 216.58.201.131         11
# ff02::1:2               7
# 216.58.211.35           7
# 224.0.0.22              6
# ff02::16                6
# 10.0.2.255              4
# ff02::1:3               4
# 224.0.0.252             4
# Broadcast               3
# 10.0.2.3                1
# PcsCompu_7d:2b:f3       1
# Name: destination, dtype: int64
# ----------------
#
# dest_port:
# 443.0      7227
# 57140.0    2749
# 41354.0    1074
# 51934.0     953
# 56256.0     655
#            ...
# 36196.0       1
# 36198.0       1
# 36204.0       1
# 36206.0       1
# 36208.0       1
# Name: dest_port, Length: 77, dtype: int64
# ----------------
#
# dest_geo:
# US                   3260
# IE                   1882
# Mountain View, US    1825
# CH                    340
# Madrid, ES             82
# London, GB             29
# Name: dest_geo, dtype: int64
# ----------------

# %% [markdown]
# # kali_http

# %%
kali.columns
# Out:
# Index(['index', 'date', 'time', 'duration', 'source', 'src_port', 'src_geo',
#        'destination', 'dest_port', 'dest_geo', 'protocol', 'length',
#        'request_method', 'arrival_time_1', 'arrival_time_2', 'info'],
#       dtype='object')

# %%
kali_protocol = kali[['index', 'protocol', 'length', 'request_method', 'info']]
kali_protocol.head()
# Out:
#    index protocol  length request_method  \
# 0      1     NBNS      92            NaN
# 1      2     NBNS      92            NaN
# 2      3     NBNS      92            NaN
# 3      4      DNS      75            NaN
# 4      5      DNS      75            NaN
#
#                                          info
# 0                   Name query NB EMPRESA<1c>
# 1                   Name query NB EMPRESA<1c>
# 2                   Name query NB EMPRESA<1c>
# 3     Standard query 0x6432 A www.maxmind.com
# 4  Standard query 0x633f AAAA www.maxmind.com

# %%
EDA.null_count(kali_protocol)
# Out:
# Presence of null in clolumns:
# index             False
# protocol          False
# length            False
# request_method     True
# info              False
# dtype: bool
#
# Number of null in columns:
# index                 0
# protocol              0
# length                0
# request_method    16906
# info                  0
# dtype: int64

# %%
EDA.null_count(kali_protocol)
# Out:
# Presence of null in clolumns:
# index             False
# protocol          False
# length            False
# request_method     True
# info              False
# dtype: bool
#
# Number of null in columns:
# index                 0
# protocol              0
# length                0
# request_method    16906
# info                  0
# dtype: int64

# %%
EDA.value_counter(kali_protocol)
# Out:
# index:
# 2047     1
# 4711     1
# 2692     1
# 12931    1
# 14978    1
#         ..
# 5432     1
# 11567    1
# 9518     1
# 15661    1
# 2049     1
# Name: index, Length: 17007, dtype: int64
# ----------------
#
# protocol:
# TCP        11236
# TLSv1.3     5446
# DNS          164
# SSDP          78
# OCSP          46
# LLMNR          8
# DHCPv6         7
# IGMPv3         6
# ICMPv6         6
# ARP            4
# NBNS           3
# DHCP           2
# BROWSER        1
# Name: protocol, dtype: int64
# ----------------
#
# length:
# 1514    7798
# 54      5935
# 60       734
# 93       727
# 89        98
#         ...
# 1256       1
# 1336       1
# 1464       1
# 1512       1
# 1407       1
# Name: length, Length: 626, dtype: int64
# ----------------
#
# request_method:
# NOTIFY      72
# POST        23
# M-SEARCH     6
# Name: request_method, dtype: int64
# ----------------
#
# info:
# Application Data [TCP segment of a reassembled PDU]                                             2818
# Application Data                                                                                1871
# Application Data, Application Data                                                               391
# Application Data, Application Data, Application Data                                             130
# NOTIFY * HTTP/1.1                                                                                 72
#                                                                                                 ...
# 41354  >  443 [ACK] Seq=2514 Ack=744983 Win=65535 Len=0                                            1
# 443  >  41360 [ACK] Seq=74554 Ack=1776 Win=32473 Len=1460 [TCP segment of a reassembled PDU]       1
# 46598  >  443 [ACK] Seq=38331 Ack=212793 Win=65535 Len=0                                           1
# 35682  >  443 [ACK] Seq=1532 Ack=432198 Win=65535 Len=0                                            1
# 36704  >  443 [ACK] Seq=1154 Ack=10719 Win=61320 Len=0                                             1
# Name: info, Length: 11299, dtype: int64
# ----------------

# %%
methods_info = kali_protocol['request_method'].value_counts()
blanks = len(kali.index) - methods_info.sum()
per = round(blanks*100 / len(kali.index), 2)
methods_info
# Out:
# NOTIFY      72
# POST        23
# M-SEARCH     6
# Name: request_method, dtype: int64

# %%
# data
methods_info.plot(kind='bar', colors = ['darkgreen', 'yellow', 'darkblue'], alpha = 0.95)

# plot
plt.title('Request Methods number')
plt.xticks(rotation = -360)

plt.show()
print(f'Aún faltan {blanks} métodos de los {len(kali.index)} registros proporcionados ({per}%)')
# Out:
# Aún faltan 16906 métodos de los 17007 registros proporcionados (99.41%)

# %%
kali_protocol['info'].value_counts().head(20)
# Out:
# Application Data [TCP segment of a reassembled PDU]                                         2818
# Application Data                                                                            1871
# Application Data, Application Data                                                           391
# Application Data, Application Data, Application Data                                         130
# NOTIFY * HTTP/1.1                                                                             72
# Client Hello                                                                                  61
# Change Cipher Spec, Application Data                                                          58
# Server Hello, Change Cipher Spec                                                              39
# Application Data, Application Data, Application Data, Application Data                        37
# Response                                                                                      23
# Request                                                                                       23
# 36220  >  443 [RST] Seq=11591 Win=0 Len=0                                                     13
# Application Data, Application Data, Application Data, Application Data, Application Data      12
# 36182  >  443 [RST] Seq=1437 Win=0 Len=0                                                      11
# Server Hello, Change Cipher Spec, Application Data, Application Data                          11
# [TCP Keep-Alive] 45028  >  80 [ACK] Seq=1855 Ack=3612 Win=63634 Len=0                         11
# Server Hello, Change Cipher Spec, Application Data                                            11
# [TCP Keep-Alive ACK] 80  >  45028 [ACK] Seq=3612 Ack=1856 Win=32397 Len=0                     11
# [TCP Keep-Alive] 59756  >  80 [ACK] Seq=1888 Ack=3509 Win=63882 Len=0                          9
# [TCP Keep-Alive ACK] 80  >  59756 [ACK] Seq=3509 Ack=1889 Win=32391 Len=0                      9
# Name: info, dtype: int64
